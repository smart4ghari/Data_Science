# %% [markdown]
# ## Python Introduction
#
# ![image.png](attachment:image.png)

# %%
import sys
sys.version
# Out:
# '3.11.3 | packaged by Anaconda, Inc. | (main, Apr 19 2023, 23:46:34) [MSC v.1916 64 bit (AMD64)]'

# %%
"Hello this is Hariharan M"
# Out:
# 'Hello this is Hariharan M'

# %% [markdown]
# ### Python Identifiers
# * Objects
# * Variables

# %%
New_name = 'Apple 3' # New_name -> identifier(variable) , 'Apple 3' is value

# %%
print(New_name)
# Out:
# Apple 3

# %% [markdown]
# ### Differnce b/w variables and functions
#
# * Function always ends with ()
# * a = 5 -> Variable
# * type() -> function

# %%
a = "Hari"
type(a)
# Out:
# str

# %%
b = 4
type(b)
# Out:
# int

# %%
c = True
type(c)
# Out:
# bool

# %%
a,b,c
# Out:
# ('Hari', 4, True)

# %%
id(a)        # Address locations
# Out:
# 2220485545968

# %%
id(b)
# Out:
# 140723631199112

# %%
id(c)
# Out:
# 140723629730336

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 2220485545968
# 140723631199112
# 140723629730336

# %%
a = [1,2,3,4,'Hari',True]

# %%
a
# Out:
# [1, 2, 3, 4, 'Hari', True]

# %%
import keyword
keyword.kwlist    # Without identifier
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
k = len(keyword.kwlist)
print(k)
# Out:
# 35

# %%
i_ = 0b11 # Binary format
i_
# Out:
# 3

# %%
bin(3)
# Out:
# '0b11'

# %%
a = 0b10
a
# Out:
# 2

# %%
a2 = 0b23
a2
# Out:
#   Cell In[8], line 1
#     a2 = 0b23
#            ^
# SyntaxError: invalid digit '2' in binary literal

# %%
# For octal 
a3 = 0o77
a3
# Out:
# 63

# %% [markdown]
# ### Float
# - Float -> the value with decimals

# %%
f = 2.3
f
# Out:
# 2.3

# %%
type(f)
# Out:
# float

# %%
f1 = 0b101.1
# Out:
#   Cell In[12], line 1
#     f1 = 0b101.1
#               ^
# SyntaxError: invalid syntax

# %%
f2 = 0o77.7
# Out:
#   Cell In[14], line 1
#     f2 = 0o77.7
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# * Integer - Value without decimal
#    - supports binary integral | octal integral
#
# * Float - Value with decimal
#    - doesn't support binary | octal

# %% [markdown]
# ### Complex datatypes
#
# - a + bj
# - a is called real part || b is called imaginary part || j - Square root of -1

# %%
o = 3 + 9j

# %%
type(o)
# Out:
# complex

# %%
o.real
# Out:
# 3.0

# %%
o.imag
# Out:
# 9.0

# %%
a3 = 2 + 3j
b3 = 7 + 8j

# %%
print(a3+b3)
print(a3-b3)
print(a3*b3)
# Out:
# (9+11j)
# (-5-5j)
# (-10+37j)

# %%
f4 = 1e1
f4
# Out:
# 10.0

# %%
f5 = 1e2
f5
# Out:
# 100.0

# %%
str1 = 'Hari
            Haran
                rd line'
str1
# Out:
#   Cell In[5], line 1
#     str1 = 'Hari
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str2 = "Hari
            Haran
                rd line"
str2
# Out:
#   Cell In[6], line 1
#     str2 = "Hari
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str3 = '''Hari
            Haran
                rd line'''
str3
# Out:
# 'Hari\n            Haran\n                rd line'
